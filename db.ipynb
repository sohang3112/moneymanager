# %%
import sqlite3
from contextlib import closing

import pandas as pd

DB_PATH = 'databases/MMAuto[GF260112](12-01-26-090617).mmbak'

# with sqlite.connect() -> auto-closes transaction but DOES NOT auto-close connection
# that's why also called contextlib.connect()
# https://blog.rtwilson.com/a-python-sqlite3-context-manager-gotcha/
# with closing(sqlite3.connect(DB_PATH)) as connection:   
#     pass  

connection = sqlite3.connect(DB_PATH)
# cursor = connection.cursor()

# %%
query = """
select datetime(t.UTIME / 1000, 'unixepoch') as dt,
       category.NAME as category,
       c.SYMBOL || ' ' || t.AMOUNT_ACCOUNT as amount,
       fromAssets.NIC_NAME as fromAsset,
       toAssets.NIC_NAME as toAsset,
       t.ZCONTENT as name, 
       t.ZDATA as description
from INOUTCOME t
join ZCATEGORY category on category.uid = t.ctgUid
join ASSETS fromAssets on fromAssets.uid = t.assetUid
left join ASSETS toAssets on toAssets.uid = t.toAssetUid
join CURRENCY c on c.uid = t.currencyUid
"""
transactions = pd.read_sql(query, connection)
transactions
# Out:
#                        dt            category     amount  \
# 0     2022-05-23 15:02:06              Salary  ₹ 17000.0
# 1     2022-05-24 01:51:24      Transportation    ₹ 600.0
# 2     2022-05-25 04:25:38      Transportation     ₹ 20.0
# 3     2022-05-25 05:53:21                Food     ₹ 10.0
# 4     2022-07-13 03:46:34              Salary   ₹ 8246.0
# ...                   ...                 ...        ...
# 2063  2026-01-11 04:19:34              Health      ₹ 5.0
# 2064  2026-01-11 11:09:32  Snacks & Beverages      ₹ 5.0
# 2065  2026-01-11 11:25:28             Kitchen    ₹ 150.0
# 2066  2026-01-11 11:32:28             Kitchen     ₹ 65.0
# 2067  2026-01-11 11:47:48              Scooty    ₹ 100.0
#
#                   fromAsset toAsset                                  name  \
# 0     ICICI Salary Account     None
# 1                Metro Card    None   Weekly home to office and back cost
# 2                      Cash    None                                  Auto
# 3       UCO Savings Account    None                           Hide & Seek
# 4               Employee PF    None      Mfilterit Salary (EPF Deduction)
# ...                     ...     ...                                   ...
# 2063                   Cash    None  Saran ashram dentist filling removal
# 2064                   Cash    None                                sweets
# 2065                   Cash    None                               Khajoor
# 2066                   Cash    None                        Bananas, Guava
# 2067                   Cash    None              Mom Scooty Duplicate key
#
#                                             description
# 0
# 1
# 2                                       Metro to Office
# 3                            From Smart Store (at work)
# 4     Automatically deducted from salary each month ...
# ...                                                 ...
# 2063
# 2064
# 2065
# 2066
# 2067
#
# [2068 rows x 7 columns]

# %%
query = """
select budgetUid, AMOUNT
from BUDGET_AMOUNT
where IS_DEL = 0
"""
budget = pd.read_sql(query, connection)
budget
# Out:
#                                        budgetUid  AMOUNT
# 0                                      9_1_0_0_6  1500.0
# 1                                      6_1_0_0_6     0.0
# 2                                     11_1_0_0_6   200.0
# 3                                     12_1_0_0_6   100.0
# 4                                     14_1_0_0_6   500.0
# 5                                     17_1_0_0_6  1000.0
# 6                                     17_1_0_0_6  1000.0
# 7                                     17_1_0_0_6  1000.0
# 8                                      6_1_0_0_6  1000.0
# 9                                      6_1_0_0_6  1000.0
# 10                                    14_1_0_0_6   500.0
# 11                                    14_1_0_0_6   500.0
# 12                                    13_1_0_0_6   200.0
# 13                                    17_1_0_0_6  1000.0
# 14                                    11_1_0_0_6   200.0
# 15                                    11_1_0_0_6   200.0
# 16                                    17_1_0_0_6   500.0
# 17                                    17_1_0_0_6   500.0
# 18  4b46ce97-65d8-4f91-b7c6-6f16b021445c_1_0_0_6   100.0
# 19                                    11_1_0_0_6   500.0
# 20                                    11_1_0_0_6   500.0
# 21  290e2a4f-b914-4bfa-bf42-d685d800a9fb_1_0_0_6   500.0
# 22                                    11_1_0_0_6  1700.0
# 23                                    11_1_0_0_6  1700.0
# 24                                    13_1_0_0_6   100.0
# 25                                    13_1_0_0_6   100.0
# 26  4b46ce97-65d8-4f91-b7c6-6f16b021445c_1_0_0_6   500.0
# 27  4b46ce97-65d8-4f91-b7c6-6f16b021445c_1_0_0_6   500.0
# 28  f212cb72-d8b1-4bcf-ac83-3cbb0b6ed33f_1_0_0_6    30.0
# 29  6619e328-ae5b-41e1-8f37-15f481c48fd4_1_0_0_6     0.0
# 30  6619e328-ae5b-41e1-8f37-15f481c48fd4_1_0_0_6     1.0
# 31  6619e328-ae5b-41e1-8f37-15f481c48fd4_1_0_0_6     1.0
# 32                                     9_1_0_0_6  1600.0
# 33                                     9_1_0_0_6  1600.0
# 34                                     9_1_0_0_6  1600.0
# 35                                    11_1_0_0_6  5000.0
# 36                                    11_1_0_0_6  5000.0
# 37                                    11_1_0_0_6  5000.0
# 38  606d902f-63ff-40b0-8da9-950f95df813f_1_0_0_6  2000.0
# 39                                    14_1_0_0_6  2500.0
# 40                                     6_1_0_0_6   500.0
# 41                                     9_1_0_0_6   500.0
# 42                                     6_1_0_0_6   500.0
# 43                                     9_1_0_0_6   500.0
# 44                                    17_1_0_0_6   100.0
# 45                                    17_1_0_0_6   100.0
# 46  4b46ce97-65d8-4f91-b7c6-6f16b021445c_1_0_0_6   100.0
# 47  4b46ce97-65d8-4f91-b7c6-6f16b021445c_1_0_0_6   100.0
# 48  4b46ce97-65d8-4f91-b7c6-6f16b021445c_1_0_0_6   500.0
# 49                                     9_1_0_0_6   700.0
# 50                                     9_1_0_0_6   700.0
# 51                                     6_1_0_0_6   700.0
# 52                                     6_1_0_0_6   700.0
# 53                                     7_1_0_0_6  5000.0
# 54                                     7_1_0_0_6   500.0
# 55                                     7_1_0_0_6   500.0
# 56  606d902f-63ff-40b0-8da9-950f95df813f_1_0_0_6   100.0
# 57  606d902f-63ff-40b0-8da9-950f95df813f_1_0_0_6   100.0

# %%
query = """
select g.ACC_GROUP_NAME as accountGroup,
       t.NIC_NAME as name,
       t.ZDATA1 as description
from ASSETS t
join ASSETGROUP g on g.uid = t.groupUid
where t.ZDATA = 0
order by t.ORDERSEQ
"""
assets = pd.read_sql(query, connection)
assets
# Out:
#      accountGroup                   name  \
# 0  Emergency Fund         Emergency Fund
# 1         Savings                   Cash
# 2         Savings    UCO Savings Account
# 3         Savings  ICICI Salary Account
# 4  Top-Up/Prepaid             Metro Card
# 5     Investments   Quant Small Cap Fund
# 6     Investments    Zerodha Kite Stocks
# 7      Retirement              ICICI PPF
# 8      Retirement            Employee PF
#
#                                          description
# 0  Goal: 10L for car or flat\n-------- OLD ------...
# 1                        3000 in bag, rest in wallet
# 2  09500110036105\nUPI: sohangchopra-1@okhdfcbank...
# 3  008701053026\nUPI: sohangchopra-1@okicici (GPa...
# 4
# 5
# 6  Discount Broker\nNeed to use instead of ICICI ...
# 7           000418476401\nMatures in 15 years (2037)
# 8  DSNHP16818210000010262\nMonthly:\nEmployee Sha...

# %%
query = """
select category.NAME as category,
       fromAssets.NIC_NAME as fromAsset,
       toAssets.NIC_NAME as toAsset,
       c.SYMBOL || ' ' || t.AMOUNT_SUB as amount,
       t.PAYEE as name,
       t.MEMO as description
from REPEATTRANSACTION t
left join ZCATEGORY category on category.uid = t.ctgUid
join ASSETS fromAssets on fromAssets.uid = t.assetUid
left join ASSETS toAssets on toAssets.uid = t.toAssetUid
join CURRENCY c on c.uid = t.currencyUid
where t.IS_DEL = 0
"""
repeat_transactions = pd.read_sql(query, connection)
repeat_transactions
# Out:
#    category              fromAsset                toAsset    amount  \
# 0    Salary            Employee PF                   None  ₹ 5000.0
# 1      None              ICICI PPF  ICICI Salary Account    ₹ 500.0
# 2  Donation    UCO Savings Account                   None  ₹ 3000.0
# 3  Donation  ICICI Salary Account                    None  ₹ 3090.0
# 4     Other  ICICI Salary Account                    None  ₹ 3000.0
# 5  Donation  ICICI Salary Account                    None   ₹ 119.0
# 6  Donation  ICICI Salary Account                    None  ₹ 2950.0
# 7  Donation  ICICI Salary Account                    None    ₹ 59.0
#
#                                            name  \
# 0         PF by HCL (Sankalp Semiconductor Ltd)
# 1                                           PPF
# 2               Newslaundry Annual Subscription
# 3                             Educate Girls NGO
# 4              Boring Money Annual Subscription
# 5          Kurzgesagt: Paid Membership: youtube
# 6                             To Scroll.in news
# 7  Sarthak Goswami Youtube channel subscription
#
#                                          description
# 0
# 1                               Minimum Contribution
# 2  AutoPay is setup via GPay till March 2033\nCan...
# 3  Autopay setup in GPay UPI, \nCan cancel from t...
# 4
# 5                           Via GPay monthly autopay
# 6                                   via GPay AutoPay
# 7

# %%
query = """
select memoDate, title, content
from MEMO
where isDel = 0
order by orderSeq
"""
notes = pd.read_sql(query, connection)
notes
# Out:
#       memoDate                                              title  \
# 0   2023-06-28                                   Noida Stay126 PG
# 1   2023-11-06                                 56k: Navi -> Quant
# 2   2023-11-05
# 3   2023-12-25                                  Chyawanprash Seva
# 4   2024-02-11                     Went to Parakh Wedding Satsang
# 5   2024-04-07  Phone Damaged, repl with Dad phone next Agra trip
# 6   2024-06-23                        Met Rishang @ Bhagat Halwai
# 7   2024-06-28                                 Changed Toothbrush
# 8   2024-08-06                                IRCTC Ticket Refund
# 9   2024-10-05                                      Left Noida PG
# 10  2024-10-14                  Dad Scooty brought to Agra home!
# 11  2024-11-06                   Abhimanyu Mama's Dad's Cremation
# 12  2024-11-19                                           Cap lost
# 13  2024-11-23                               Took OD vomit tablet
# 14  2025-01-31                               DEI visited open day
# 15  2025-02-01                  NOT PAYING QUANT SIP THIS MONTH!
# 16  2025-02-05                  One-day trip, Delhi elections day
#
#                                               content
# 0   Mom paid Rs. 32,500 (2 months advance, 1 month...
# 1                                                  \n
# 2   20k RD transfer got missed due to less funds i...
# 3   Monday-Saturday: 25-30 December\n9 a.m. - ~4:1...
# 4                                                  \n
# 5                                                  \n
# 6                                                  \n
# 7                                                  \n
# 8   Vande Bharat : received Rs. 1.5K, charge: Rs. ...
# 9   Monu (Stay126 PG owner) didn't refund Rs. 15K ...
# 10                                                 \n
# 11                                                 \n
# 12       Spotty cap blown away while driving scooty\n
# 13  Felt stomach nausea (like I do every morning) ...
# 14                                  Akele hi maze! \n
# 15  Can't afford it, because I invested 50k in GSP...
# 16  So vote, and also meet friends. \n= Agra: Brea...
